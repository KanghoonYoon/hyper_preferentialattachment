# %%
import os
import pandas as pd
from src.utils import *
from src.data_utils import *
from matplotlib import pyplot as plt

# %%
# path = os.getcwd() + '/project_data/' + 'paper_author.txt'
# data = Hypergraph(path=path)

path = os.getcwd() + '/save_graph/' + '1' + 'th5000iter10threshold.txt'
data = Updategraph(path)
query = Query()

New_occur = []

for i in range(len(query.query)):

    try:
        for node in query.query[i]:
            d = data.degrees[node]
        New_occur.append(0)

    except:
        New_occur.append(1)


one_hot = dict()
one_hot['New_occur'] = New_occur
one_hot = pd.DataFrame(one_hot)

Degree_difference = []
Max_degree = []
Avg_degree = []
MIN_distance=[]
Avg_cluster_coef = []
Avg_jaccard = []
Hyper_jaccard = []
Adamic_adar = []


# Max_closeness = []
# Avg_closeness = []

# node_close = node_closeness(data)  # dict : node -> value
cluster_coefficient = cluster_coef(data)  # dict : node -> value


for i in range(len(query.query)):

    degs = []
    # clsness = []
    cls_coef = []
    for node in query.query[i]:
        try:
            # clsness.append(node_close[node])
            cls_coef.append(cluster_coefficient[node])
        except:
            # clsness.append(0)
            cls_coef.append(0)

        try:
            degs.append(data.degrees[node])
        except:
            degs.append(0)


    # Max_closeness.append(max(clsness))
    # Avg_closeness.append(np.average(clsness))
    Avg_cluster_coef.append(np.average(cls_coef))
    Max_degree.append(max(degs))
    Degree_difference.append(max(degs) - min(degs))
    Avg_degree.append(np.average(degs))

    min_dist = get_distance(Data_class=data, hyperedge=query.query[i])
    MIN_distance.append(min_dist)

    Hyper_jaccard.append(jaccard_hyper(Data_class=data, hyperedge=query.query[i]))
    Avg_jaccard.append(averaged_jaccard_similarity(Data_class=data, edge=query.query[i]))

    try:
        Adamic_adar.append(adamic_adar(data, query.query[i]))
    except:
        Adamic_adar.append(0)

    if i%500 ==0:
        print(i,"th")


Answer =[]

for i in range(len(query.query)):
    Answer.append(1*query.answer[i])

dataframe = dict()

dataframe['Degree_difference'] = Degree_difference
dataframe['Max_degree'] = Max_degree
dataframe['Avg_degree'] = Avg_degree
dataframe['MIN_distance'] = MIN_distance
# dataframe['Max_closeness'] = Max_closeness
# dataframe['Avg_closeness'] = Avg_closeness
dataframe['Avg_cluster_coef'] = Avg_cluster_coef
dataframe['Avg_jaccard'] = Avg_jaccard
dataframe['Hyper_jaccard'] = Hyper_jaccard
dataframe['Adamic_adar'] = Adamic_adar

dataframe['Answer'] = Answer

dataframe = pd.DataFrame(dataframe)

path = 'processed_data/'
# dataframe.to_csv(path+ str(j)+'th5000_update.csv', index=False)
# one_hot.to_csv('processed_data/'+'one_hot.csv', index=False)
# Out:
# 0 th
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a6419abbfe47> in <module>
#      67     Avg_degree.append(np.average(degs))
#      68
# ---> 69     min_dist = get_distance(Data_class=data, hyperedge=query.query[i])
#      70     MIN_distance.append(min_dist)
#      71
#
# ~\code\src\utils.py in get_distance(Data_class, hyperedge)
#     121                     min_distance = 4
#     122                 continue
# --> 123             set1 = get_radius_neighbors(Data_class, set(), hyperedge[i], 1, 3)
#     124             difference = set1.intersection(set2)
#     125             if not difference:
#
# ~\code\src\utils.py in get_radius_neighbors(Data_class, neighbors, nodeID, iter, max_iter)
#      39     neighbors = old_neighbors.union(new_neighbors)
#      40     for node in difference:
# ---> 41         neighbors = get_radius_neighbors(Data_class, neighbors, node, iter+1, max_iter)
#      42     return neighbors
#      43
#
# ~\code\src\utils.py in get_radius_neighbors(Data_class, neighbors, nodeID, iter, max_iter)
#      38         return neighbors
#      39     neighbors = old_neighbors.union(new_neighbors)
# ---> 40     for node in difference:
#      41         neighbors = get_radius_neighbors(Data_class, neighbors, node, iter+1, max_iter)
#      42     return neighbors
#
# KeyboardInterrupt:
